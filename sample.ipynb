# %%
# !pip install transformers
# !pip install NLTK
import nltk
nltk.download('vader_lexicon')
# Out:
# Collecting transformers
#   Downloading transformers-4.32.0-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 49.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.2 tokenizers-0.13.3 transformers-4.32.0
# Requirement already satisfied: NLTK in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from NLTK) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from NLTK) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from NLTK) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from NLTK) (4.66.1)
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader, TensorDataset
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn.modules.loss import _WeightedLoss
from torchtext.data.metrics import bleu_score
import tensorflow as tf
import tensorflow_hub as hub
from transformers import AutoTokenizer, AutoModel
from transformers import AdamW, get_linear_schedule_with_warmup
from collections import defaultdict
import math
import re
import csv
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
import os

# %%
def prepare_input(data, model, tokenizer):
    batch_size = 64
    input_ids, token_type_ids, attention_mask = [], [], []
    print("tokenization starts")

    for i in range(0, len(data), batch_size):
        batch = data[i:i+batch_size]
        batch_tokens = tokenizer(batch, truncation=True, padding='max_length', max_length=128)

        #csv.writer(input_file, delimiter=' ').writerows(batch_tokens["input_ids"])
        #csv.writer(type_file, delimiter=' ').writerows(batch_tokens["token_type_ids"])
        #csv.writer(att_file, delimiter=' ').writerows(batch_tokens["attention_mask"])
        input_ids.extend(batch_tokens["input_ids"])
        token_type_ids.extend(batch_tokens["token_type_ids"])
        attention_mask.extend(batch_tokens["attention_mask"])

    print("tokenization done")


    tensor_input_ids = torch.tensor(input_ids).to(torch.int64)
    tensor_token_ids = torch.tensor(token_type_ids).to(torch.int64)
    tensor_attention = torch.tensor(attention_mask).to(torch.int64)

    dataset = TensorDataset(tensor_input_ids, tensor_token_ids, tensor_attention)
    dataloader = DataLoader(dataset, batch_size=batch_size)

    model.to(device)
    model.eval()


    res = []


    for batch in dataloader:

        b_input_ids, b_token_type, b_input_mask = batch

        with torch.no_grad():

            outputs = model(b_input_ids.to(device), token_type_ids=b_token_type.to(device),
                        attention_mask=b_input_mask.to(device))
            hidden_states = outputs[2][-1]

            res.append(hidden_states.cpu().numpy())


    return res, input_ids

# %% [markdown]
# **Data Preprocessing**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased", output_hidden_states=True)
model.to(device)
df = pd.read_csv("mt_subset_spacy.csv") # this is a sample provided for you
data = df["text"].to_list()

ans, input_ids = prepare_input(data, model, tokenizer)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenization starts
# tokenization done

# %%
np.save("embeddings.npy", np.concatenate(ans, axis=0))  # its good to save this data so that you save time for next run

# %%
data = np.load("embeddings.npy")
data.shape
# Out:
# (2404, 128, 768)

# %% [markdown]
# **Start Experiment**

# %%
class SmoothCrossEntropyLoss(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    def k_one_hot(self, targets:torch.Tensor, n_classes:int, smoothing=0.0):
        with torch.no_grad():
            targets = torch.empty(size=(targets.size(0), n_classes),
                                  device=targets.device) \
                                  .fill_(smoothing /(n_classes-1)) \
                                  .scatter_(1, targets.data.unsqueeze(1), 1.-smoothing)
        return targets

    def reduce_loss(self, loss):
        return loss.mean() if self.reduction == 'mean' else loss.sum() \
        if self.reduction == 'sum' else loss

    def forward(self, inputs, targets):
        assert 0 <= self.smoothing < 1

        targets = self.k_one_hot(targets, inputs.size(-1), self.smoothing)
        log_preds = F.log_softmax(inputs, -1)

        if self.weight is not None:
            log_preds = log_preds * self.weight.unsqueeze(0)

        return self.reduce_loss(-(targets * log_preds).sum(dim=-1))

# %%
# testing loss function
crit = SmoothCrossEntropyLoss(smoothing=0.5)
predict = torch.FloatTensor([[0, 0.2, 0.7, 0.1, 0],
                            [0, 0.9, 0.2, 0.2, 1],
                            [1, 0.2, 0.7, 0.9, 1]])
v = crit(Variable(predict),
        Variable(torch.LongTensor([2, 1, 0])))
print(v)
# Out:
# tensor(1.5161)

# %%
#The decoder model architecture
model.to("cpu")
class Decoder(nn.Module):
    def __init__(self, nhead=8, num_layers=6, d_model=768, constrained_embedding=True, d_pos=512, vocab=None, sequence_memory=False,
                pos_embedding = model.embeddings.position_embeddings.weight, word_embedding=model.embeddings.word_embeddings.weight ):
        super(Decoder, self).__init__()
        decoder_layer = nn.TransformerDecoderLayer(d_model=d_model, nhead=nhead, batch_first=True)
        ##initialize transformer decoder
        self.transformer =  nn.TransformerDecoder(decoder_layer, num_layers=num_layers)
        ##initialize position encoding
        self.pos_embedding = nn.Embedding(d_pos, d_model)
        self.pos_embedding.weight = nn.Parameter(pos_embedding)
        self.pos_embedding.weight.requires_grad = False
        ##initialize projection layer
        #self.projection = nn.Linear(768, 28996, bias=False)
        if constrained_embedding:
            self.word_embedding = nn.Parameter(torch.index_select(word_embedding,0,vocab))
        else:
            self.word_embedding = nn.Parameter(word_embedding)
        self.word_embedding.requires_grad = True
        self.sequence_memory = sequence_memory
        #self.activation = nn.Softmax(dim=-1)

    def forward(self,de_input, memory):
        de_input_pos_emd = self.pos_embedding(torch.arange(de_input.shape[1]).to(device))
        de_input = de_input + de_input_pos_emd.unsqueeze(0).repeat(de_input.shape[0],1,1) ###add positional encoding to decoder input
        if not self.sequence_memory:
            memory = memory.unsqueeze(1).repeat(1,de_input.shape[1],1)
        memory = memory + de_input_pos_emd.unsqueeze(0).repeat(de_input.shape[0],1,1) ###add positional encoding to memory
        x = self.transformer(de_input, memory)

        #y = self.projection(x)
        y = torch.matmul(x, self.word_embedding.t())
        return y

# %%
class clinical_embedding(Dataset):
    def __init__(self, text, de_input,transform=None, target_transform=None):
        self.text = text
        self.de_input = de_input
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return self.text.shape[0]

    def __getitem__(self, idx):
        X = self.text[idx]
        memory = torch.Tensor(X).to(torch.float32)
        de_input = torch.tensor(self.de_input[idx]).to(torch.int64)
        target = torch.roll(de_input, -1, dims=0)
        target[-1] = 0
        #target = F.one_hot(target, num_classes=28996)
        de_input = model.embeddings.word_embeddings(de_input)

        sample = {"memory": memory, "target": target, "de_input": de_input}

        return sample


def vec_translate(a, my_dict):
        return np.vectorize(my_dict.__getitem__)(a)

batch_size = 60
sequential_embedding = True

embeddings = np.load("embeddings.npy")
tgt = input_ids
tgt = tgt[:len(embeddings)]
vocab = np.unique(tgt)

idx_2_token = {}
token_2_idx = {}
for idx, token in enumerate(vocab):
    idx_2_token[idx] = token
    token_2_idx[token] = idx
vocab = torch.Tensor(vocab).to(torch.int64)
new_tgt= vec_translate(tgt, token_2_idx)

X_tr_mem, X_test_mem, y_tr_dein, y_test_dein = train_test_split(embeddings, new_tgt, test_size=0.1, random_state=2022)

### convert decoder input into one hot target

training_data = clinical_embedding(X_tr_mem, y_tr_dein)
test_data = clinical_embedding(X_test_mem, y_test_dein)
train_dataloader = DataLoader(training_data, batch_size, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size, shuffle=True)

# %%
def train_epoch(model, data_loader, loss_fn, optimizer, device, scheduler, n_examples):
    model.to(device)
    model = model.train()
    losses = []
    for d in data_loader:
        memory = d["memory"].to(device)
        de_input = d["de_input"].to(device)
        targets = d["target"].to(device)

        outputs = model(
                de_input,
                memory
                )

        loss = loss_fn(outputs.view(-1, outputs.shape[-1]), torch.flatten(targets))
        losses.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()
    return  np.mean(losses)

# %%
def eval_model(model, data_loader, loss_fn, device, n_examples):
    model = model.eval()
    losses = []

    with torch.no_grad():
        for d in data_loader:
            memory = d["memory"].to(device)
            de_input = d["de_input"].to(device)
            targets = d["target"].to(device)
            outputs = model(
                      de_input,
                      memory)
            loss = loss_fn(outputs.view(-1, outputs.shape[-1]), torch.flatten(targets))
            losses.append(loss.item())
    return np.mean(losses)

# %% [markdown]
# **Train your decoder**

# %%
EPOCHS = 20
decoder = Decoder(vocab=vocab, num_layers=6, sequence_memory=sequential_embedding)
decoder.to(device)
optimizer = AdamW(decoder.parameters(), betas=(0.9, 0.98), eps=1e-9, lr=0.0001)
total_steps = len(train_dataloader) * EPOCHS
scheduler = get_linear_schedule_with_warmup(
  optimizer,
  num_warmup_steps=300,
  num_training_steps=total_steps
)
#loss_fn = nn.CrossEntropyLoss(size_average=False, ignore_index=0)
loss_fn = SmoothCrossEntropyLoss(smoothing=0.5)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
#train/finetune the decoder
#for simlicity, the pretraining is skipped here, refer to Sec. 9
history = defaultdict(list)
best_ce = float("inf")
patience = 2
for epoch in range(EPOCHS):
    print(f'Epoch {epoch + 1}/{EPOCHS}')
    print('-' * 10)
    train_loss = train_epoch(
                            decoder,
                            train_dataloader,
                            loss_fn,
                            optimizer,
                            device,
                            scheduler,
                            len(X_tr_mem)
                            )
    print(f'Train loss {train_loss} ')
    val_loss = eval_model(
                        decoder,
                        test_dataloader,
                        loss_fn,
                        device,
                        len(X_test_mem)
                        )
    print(f'Val   loss {val_loss} ')
    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    if val_loss < best_ce:
        torch.save(decoder.state_dict(), 'finetuned_decoder_state.bin')
        best_ce = val_loss
        patience = 0
    else:
        patience += 1
        if patience > 2:
            break
# Out:
# Epoch 1/20
# ----------
# Train loss 6.994896231470881
# Val   loss 5.688381195068359
# Epoch 2/20
# ----------
# Train loss 5.4508769576613965
# Val   loss 5.309327125549316
# Epoch 3/20
# ----------
# Train loss 5.279418893762537
# Val   loss 5.210868549346924
# Epoch 4/20
# ----------
# Train loss 5.223765746967213
# Val   loss 5.176285171508789
# Epoch 5/20
# ----------
# Train loss 5.188881642109639
# Val   loss 5.247062492370605
# Epoch 6/20
# ----------
# Train loss 5.164689772837871
# Val   loss 5.214378356933594
# Epoch 7/20
# ----------
# Train loss 5.144145991351153
# Val   loss 5.162922191619873
# Epoch 8/20
# ----------
# Train loss 5.117914161166629
# Val   loss 5.107823371887207
# Epoch 9/20
# ----------
# Train loss 5.091563482542296
# Val   loss 5.099489402770996
# Epoch 10/20
# ----------
# Train loss 5.0684392903302165
# Val   loss 5.097560024261474
# Epoch 11/20
# ----------
# Train loss 5.046686262697787
# Val   loss 5.126954650878906
# Epoch 12/20
# ----------
# Train loss 5.026753928210284
# Val   loss 5.055900382995605
# Epoch 13/20
# ----------
# Train loss 5.00520878869134
# Val   loss 5.029260063171387
# Epoch 14/20
# ----------
# Train loss 4.987658732646221
# Val   loss 5.014658069610595
# Epoch 15/20
# ----------
# Train loss 4.974275692089184
# Val   loss 5.027562522888184
# Epoch 16/20
# ----------
# Train loss 4.962341759655927
# Val   loss 4.999736022949219
# Epoch 17/20
# ----------
# Train loss 4.953818462990426
# Val   loss 4.973461532592774
# Epoch 18/20
# ----------
# Train loss 4.946585075275318
# Val   loss 5.012159824371338
# Epoch 19/20
# ----------
# Train loss 4.942913184294829
# Val   loss 4.967530822753906
# Epoch 20/20
# ----------
# Train loss 4.940123081207275
# Val   loss 4.972396183013916

# %% [markdown]
# **Inference**

# %%
import string
exclude = " ".join(list(string.punctuation)+["[PAD]"])
filter_set = tokenizer.encode(exclude)

# %%
bert = model
def inference(model,tgt, mem, idx_2_token, prefix=0, max_len=10, beam_size=20):
    model.eval()
    tgt = np.expand_dims(tgt, 0)
    mem = np.expand_dims(mem,0)
    hypothesis = torch.Tensor(tgt).to(torch.int64)
    hypothesis[:,1:] = 0
    hypotheses = []
    mem = torch.Tensor(mem).to(torch.float32)
    ### BOS: 101 ; EOS: 102 ; padding 0


    de_input = bert.embeddings.word_embeddings(hypothesis)
    outputs = model(de_input.to(device),
                        mem.to(device))
    for pos in range(max_len):
        tokens = torch.topk(outputs[:,pos,:], beam_size).indices
        #values = torch.topk(outputs[:,idx,:], beam_size).values
        #values = F.gumbel_softmax(values, tau= 3,dim=-1)
        #values_ = np.squeeze(values.cpu().detach().numpy())
        hypothesis = torch.zeros(tgt.shape, dtype=torch.int64)
        for j in range(beam_size):
            idx = tokens[0][j].item()
            token = idx_2_token[idx]

            if (token>200) and (token not in filter_set):
                hypothesis[:,j+1] = token
        hypotheses.append(hypothesis)

    ground_truth = tokenizer.decode(np.trim_zeros(np.squeeze(vec_translate(tgt, idx_2_token))[1:])).strip("[SEP]")
    #decoded = tokenizer.decode(torch.squeeze(hypothesis)[1:]).strip(" [PAD] ")
    all_translations = []
    for hypo in hypotheses:
        decoded = tokenizer.decode(np.squeeze(hypo)[1:]).strip(" [PAD] ")
        all_translations.append(decoded)
    return (ground_truth, all_translations)

# %% [markdown]
# Evaluate on test set

# %%
res=inference(decoder, y_test_dein[0], X_test_mem[0], idx_2_token, beam_size=20)
print("-"*10 + "groundtruth" + "-"*10)
print(res[0])
print("-"*10 + "Reconstructions" + "-"*10)
for i in range(10):
    print(res[1][i])
# Out:
# ----------groundtruth----------
# partial proximal obstruction patent distal system
# ----------Reconstructions----------
# the a no this right general operation an [PAD] without neck his obstruction operative superior patent left radical was
# bladder patent obstruction common patient pending partial otherwise per nasal artery via islous closure tract necessitatedhm
# bladder obstruction patent partial pending of common point failure appliedrencewayucible [PAD] otherwise nasal via arteryfle
# pending obstruction patent partial of bladder [PAD] commonhr viarantuciblemas procedure closure applieddder failure artery
# of pending [PAD] and bladder applied patent partialhr obstruction artery common failure via [PAD]omy br conductchner
# pending [PAD] partial ofomy obstruction patent failure arteryhrrence bladder applied andym procedure traction common conduct
# pending [PAD] obstruction partialrencehr patent bladder bilateral ofym closure common viaomy traction and nasal br
# pending partial bladderhr of obstruction appliedrence nasal traction patent section br andomy distal via recent
# pending partial obstructionrencehr sectionomy of bladder traction brhora patent nasalym bypass applied common
# pending obstructionrencehr partialomy applied patent ofhora br bladder nasal distal recent bilateralusionhil

# %%
import random
bert = model
def translate(model,tgt, mem, max_len, idx_2_token, beam_size=5, prefix=3, temp=2.5):
    model.eval()
    tgt = np.expand_dims(tgt, 0)
    mem = np.expand_dims(mem,0)
    hypothesis = torch.Tensor(tgt).to(torch.int64)
    hypothesis[:,prefix+1:] = 0
    mem = torch.Tensor(mem).to(torch.float32)
    ### BOS: 101 ; EOS: 102 ; padding 0
    #consecutive = 0
    for i in range(prefix, max_len):
        de_input = bert.embeddings.word_embeddings(hypothesis)
        outputs = model(de_input.to(device),
                        mem.to(device))
        tokens = torch.topk(outputs[:,i,:], beam_size).indices
        values = torch.topk(outputs[:,i,:], beam_size).values
        values = F.gumbel_softmax(values, tau= temp,dim=-1)
        values_ = np.squeeze(values.cpu().detach().numpy())
        for j in range(beam_size):
            k = np.random.choice(beam_size,1, p=values_)
            idx = tokens[0][k].item()
            token = idx_2_token[idx]

            if (token>200) and (token not in hypothesis[:,:i+1])and (token not in filter_set):
                hypothesis[:,i+1] = token
                #if i < prefix+1: break
                break
        if token == 102 or token == 0:
            break
    for i in range(prefix+1):
        hypothesis[:,i] = idx_2_token[hypothesis[:,i].item()]
    ground_truth = tokenizer.decode(np.trim_zeros(np.squeeze(vec_translate(tgt, idx_2_token))[1:])).strip("[SEP]")
    decoded = tokenizer.decode(torch.squeeze(hypothesis)[1:]).strip(" [PAD] ")
    #decoded = decoded[:len(ground_truth)]
    return (ground_truth, decoded)

# %% [markdown]
# transferbility, this evaluate the decoder on another dataset

# %%
cms = pd.read_csv('cms_spacy.csv', header="infer")
label = cms["spacy_label"]
# again generate input for this dataset
cms_embedding, _ = prepare_input(cms["text"].tolist(), model, tokenizer)
cms_embedding = np.concatenate(cms_embedding, axis=0)

"""
code = {"ATL": "Atlanta",
        "DFW": "Dallas",
        "DEN": "Denver",
        "ORD": "Chicago",
        "LAX": "Los Angeles",
        "CLT": "Charlotte",
        "LAS": "Las Vegas",
        "PHX": "Phoenix",
        "MCO": "Orlando",
        "SEA": "Seattle",
        "MIA": "Miami",
        "IAH": "Houston",
        "JFK": "New York",
        "FLL": "Fort Lauderdale",
        "EWR": "Newark",
        "SFO": "San Francisco",
        "MSP": "Minneapolis",
        "DTW": "Detroit",
        "BOS": "Boston",
        "SLC": "Salt Lake City"
       }
"""
# Out:
# tokenization starts
# tokenization done
# '\ncode = {"ATL": "Atlanta",\n        "DFW": "Dallas",\n        "DEN": "Denver",\n        "ORD": "Chicago",\n        "LAX": "Los Angeles",\n        "CLT": "Charlotte",\n        "LAS": "Las Vegas",\n        "PHX": "Phoenix",\n        "MCO": "Orlando",\n        "SEA": "Seattle",\n        "MIA": "Miami",\n        "IAH": "Houston",\n        "JFK": "New York",\n        "FLL": "Fort Lauderdale",\n        "EWR": "Newark",\n        "SFO": "San Francisco",\n        "MSP": "Minneapolis",\n        "DTW": "Detroit",\n        "BOS": "Boston",\n        "SLC": "Salt Lake City"\n       }\n'

# %%
model.to("cpu")
def transfer_translate(model, mem, max_len, idx_2_token, beam_size=5, prefix=3, temp=2.5):
    model.eval()
    tgt=torch.zeros(128)
    tgt = np.expand_dims(tgt, 0)
    mem = np.expand_dims(mem,0)
    hypothesis = torch.Tensor(tgt).to(torch.int64)
    #hypothesis[:,prefix+1:] = 0
    mem = torch.Tensor(mem).to(torch.float32)
    ### BOS: 101 ; EOS: 102 ; padding 0
    #consecutive = 0
    for i in range(prefix, max_len):
        de_input = bert.embeddings.word_embeddings(hypothesis)
        outputs = model(de_input.to(device),
                        mem.to(device))
        tokens = torch.topk(outputs[:,i,:], beam_size).indices
        values = torch.topk(outputs[:,i,:], beam_size).values
        values = F.gumbel_softmax(values, tau= temp,dim=-1)
        values_ = np.squeeze(values.cpu().detach().numpy())
        for j in range(beam_size):
            k = np.random.choice(beam_size,1, p=values_)
            idx = tokens[0][k].item()
            token = idx_2_token[idx]

            if (token>200) and (token not in hypothesis[:,:i+1])and (token not in filter_set):
                hypothesis[:,i+1] = token
                #if i < prefix+1: break
                break
        if token == 102 or token == 0:
            break
    for i in range(prefix+1):
        hypothesis[:,i] = idx_2_token[hypothesis[:,i].item()]
    decoded = tokenizer.decode(torch.squeeze(hypothesis)[1:]).strip(" [PAD] ")

    return decoded

# %%
#reconstruct the sentences
#try first 100 samples
Ground_truth = []
Prediction = []
for i in range(100):
    Res = []
    for j in range(10):
        res = transfer_translate(decoder, cms_embedding[i], 15, idx_2_token, prefix=0 , beam_size=10, temp=2)
        Res.append(res)
    print("-"*10 + str(i) + "-"*10)
    gt = cms["text"].iloc[i]
    print(gt)
    print("-"*21)
    Prediction.append(Res)
    Ground_truth.append(gt)
    for k in range(10):
        print(Res[k])
# Out:
# ----------0----------
# hospital observation care on day of discharge
# ---------------------
# the bladderponpsage and was gall [PAD]uteriter [PAD]rp bio ct
# an and sterile
# general an padudge and wastail the without bun dr
# the pad for induction arrest injectionificder [PAD]age surgery physician pathology condition dr
# the care diagnostic
# heart waslang [PAD] statusalhalyr lapage due or microscope
# heart and waslangemayst needle
# the careage hemural was lab
# this bro the of labemcoax
# anressed catyleylaillailaril
# ----------1----------
# hospital observation care, typically 70 minutes
# ---------------------
# this for par an and or the
# thistail the foricalutionuter
# this insulin condition [PAD] and sterileage drison the without
# a forillailleilillo to
# this for par overnight pending morning the distal
# a insulin the and or was await repeat
# the care nurse and wasramco bunusnos nasal shave shaved
# heartstation [PAD] equals was grafyst [PAD] minutes years months weeksmal conditionase
# an was echoterol the withoutage
# the pad was trialinennen yearsmal condition conditions
# ----------2----------
# initial hospital inpatient care, typically 30 minutes per day
# ---------------------
# an auration
# noic duration nasal inc overs [PAD] schedule minutes seconds morning the pending [PAD] late
# a with the and is prep prepared preparation conditioniciaic nasal wasrp region
# a on weremal repeat waslip the condition repair shoulder without no rate or
# heart isram and distal condition repeat
# blood aressedress the wasramilla schedule condition repeatnia fashioniligul
# no dia
# general an and [PAD] rates distal was the to sterile defect pathology region area
# the to an was prep condition conditions care gallo bun
# nonalal today repeat wassco revision intermittent the without and
# ----------3----------
# initial hospital inpatient care, typically 70 minutes per day
# ---------------------
# blood or and physician therapytherapy the a general
# the ofyle post waslang and or any secondary mu pending [PAD] full seconds
# this ultrasound for schedule wascardage condition bun aniliici
# an the and respiratory is cardcard [PAD] congestioniteritisionization bleedingemia
# the care management hem thor medrr years schedulestistic conditionicia post and
# thiscard or ste dilstis condition dr triciteurationisonisionudge
# an
# heart wasmal distal hem per conditionat schedules med
# this to an sterile the care [PAD] preage dr
# nonal and exam examination conditioniciaicoio repeat
# ----------4----------
# subsequent hospital inpatient care, typically 25 minutes per day
# ---------------------
# this ultrasound and physician therapy dr br ct ca distal size care medicine conditionuf
# no care nurse and is tailor was sterileuresuration [PAD] rate joint mmmm
# no care repair continuation the and
# noara dil liga dia and scissors solution condition [PAD] ofurationus
# this for nasal tract position today drain drains drained [PAD] approximately condition [PAD] of abdominal
# the and or rate renal anresseduraluria
# general orpatient care fracture fractures antibiotics the sterileuresscoco region 200 therapy
# this axialage syndromel nooh
# a undericoic duration contrastallas hyper post shoulder was and rate or
# heart and wasramlip the conditionuf
# ----------5----------
# subsequent hospital inpatient care, typically 35 minutes per day
# ---------------------
# the and or distal wascard
# the and is induction repeat fashionlyusnosnosis condition conditionstory region 250
# nonalnousiac care diagnostical today conditionicia refifice was med therapy
# a per yearsmal fracture antibiotics dr pressure an
# anressressedrum [PAD]rbin and or without ref detution suite pending region
# anressed [PAD] time today drain drains drained the and pending daysmal blade knife
# the of phaseal prof vicvac and sterile defect [PAD]imeterution
# the and was padudge condition awaitlip
# the in trial physicianural
# noic per given procedure procedures tape
# ----------6----------
# hospital discharge day management, 30 minutes or less
# ---------------------
# bloodfiinen infectionural and pending awaitere or bun an
# general and is induction galloed care surgeryution
# bloodus and infection 59 yearsmal condition ref replacement replaced without or problems pending
# a perlang [PAD] 15 was stitch sewing lad the wire conditionuter [PAD]yle
# the and ormplang [PAD] timeage bleeding stitch stitches dental nasalificeision
# a and is induction pending given nasal the
# an and the to wasmp orage conditionicia bunison pending drrp
# a placement prep as trialthy waslangili conditioncoatps bleeding bleed
# heart waslangema isram pending [PAD] minutes minute
# no anyrant or and the pad
# ----------7----------
# hospital discharge day management, more than 30 minutes
# ---------------------
# this axial and wasram condition
# aurationus the and or condition repair measures minutes seconds
# no and for trial ismal pad bun [PAD]ifice condition 250 200
# an is areiciaonia pending [PAD] per size restageitis time bleeding rate
# this and the was hem peruter for repeat condition 250 500
# a per was hem bard and pending week days minutes yearsmatetory drison
# the and to was hemrom or years
# the and waslangema isram
# a per wasmp or without pounds years months days distal and rate ratio minutes
# blood without minute a shave or and condition ca the limits minimum maximum
# ----------8----------
# critical care delivery critically ill or injured patient, first 30-74 minutes
# ---------------------
# heart orcard card neous radialution pending [PAD] approximately condition strain [PAD] years
# general the was and microscopestation yearsmal
# a cap caps or without
# deep or steioriac cardiac and waslip pending awaitution
# thiscard and pending await fracture opnat the care condition conditionsint etc or
# an was branch or exam
# a induction arrest without denies denied or ste pendingeriysisyticous and surgery
# the care or microscope ste amp oversiter um bunema pa proneous nasal
# deep and or tous was ste amp pending
# no without [PAD] respiratory islip and or pending bun rev was distal shoulder shoulders
# ----------9----------
# pathology examination of tissue using a microscope, moderately low complexity
# ---------------------
# thisific of examination present the and
# the to wascard or
# the pad without with microscope ct bioicia and pending awaitlip scissors [PAD] of
# the and weresto trans pending [PAD]san without [PAD]eloano bio limitsures
# a of echo and waslangotti
# and gall liga revision instrument present
# a using an wasram the specimen and
# the without sterile microscope bio [PAD] of and
# the pad without examination exam
# this for thinile excellent ct countuteriter [PAD]pres and or pending
# ----------10----------
# pathology examination of tissue using a microscope, intermediate complexity
# ---------------------
# general and the a microscope
# the without or and microscope defecty [PAD]ngo limits balance
# no without and ultrasound mri examination the specimen defect or microscope sterile pathology
# the of sterile pad and waslangtag [PAD] equalsps
# general the of bioic without [PAD] et as scissors
# a and was infection infections dr or the specimen microscope sterile present pad mri ultrasound
# and was echo corona
# aicular of and
# this chronic and were areram the pending [PAD] equals speed scissors limits size
# no without the to and or was gallusa vicifice [PAD] spreads defect sterile
# ----------11----------
# special stained specimen slides to identify organisms including interpretation and report
# ---------------------
# the and or counts bion were those
# no counts count to and microscopeps the pending bleeding injuries injury tissue tissues pathology
# all the of microscopeps for await bleeding and scissors [PAD] history pathology reconstruction dr
# no report reports photos photo to sterile and pending etc or microscope eye the
# a report findings were testing inspection to specimen or infectionem
# this and were areram pad the was [PAD] versus
# the and to were are diariesies
# an the to forome were diaries vic [PAD] versus
# this forcopic the and were report reportsiga cp pending pathology mri ultrasound
# an and was echo mirror the microscope correct properrum without sterile
# ----------12----------
# special stained specimen slides to examine tissue including interpretation and report
# ---------------------
# the were are and microscope correct deviation
# an werellar
# the as were counts counties pathologyhia or microscopegnanuni cpsco bio
# nonalnius the and were are count counts [PAD] ofporembomb
# this and was wereicia through the to pathology
# wereps and microscope viewstaticuter
# the and were counts [PAD] to was nod shaved
# an a for weregraphs the and was sterile pathology
# an and waslang [PAD] taken specimen specimensmen tissues the
# an weremalma the and wasram specimenmbo without or defect case pathology
# ----------13----------
# special stained specimen slides to examine tissue
# ---------------------
# an case defect patent pending bleeding fracture tissue brushcted pathology dr contrast foreign the
# a res on is exam
# a supplyingrum
# a of wereicia
# the specimen needle weremal defect
# the for wire com graf
# nonal waslanghg
# all for test testing was and sterile pathologyiology condition ring eye lens camera limits
# a applied or weremal vic ultrasound the wasoc without defect fracture conditionmpt
# this to and weredine the
# ----------14----------
# tissue or cell analysis by immunologic technique
# ---------------------
# anressed cat electro hem done and the
# the for trialthy malius without was wereicia [PAD] versus etcglrom
# this forcardage and wereicia [PAD] use or was gallcerceal
# the forcard or em wasram pad and pathology therapy treatmentromomy
# thisramlangotti
# the pad echo [PAD] using wasramma and microscope [PAD] typeryccignan
# an waslangrom hem [PAD] body or without absent pending [PAD] versus andgnan
# a using utilizing incgmrom
# noano and trialthy
# this fa injection wereiolromram or
# ----------15----------
# antibody evaluation
# ---------------------
# the placement performedrum
# the was and
# and
# a test and trialusa
# heart and the needle
# waslang
# and
# the
# this for test testinguter wasram and trial
# the trialthy and [PAD] fortou ct field dr
# ----------16----------
# electron microscopy for diagnosis
# ---------------------
# the for test testingal without inspection examination and scissors fracture ultrasound pathologyase radio
# this test lab microscope ultrasound without pending mass and pathologyiology
# mass and ultrasound wasram fractureural jointilol
# bioal [PAD] test ct mass
# mass masses forpres
# bio
# for mass and
# mass were bio [PAD] done ct fracture fractures pending pathologytology dr
# the ofrumision ultrasound
# bio ur the microscope ultrasound [PAD] contrast ct field mass masses
# ----------17----------
# microscopic genetic analysis of tumor
# ---------------------
# mass masses sheets noted were tumorma defectnosis pathology dr sterile [PAD] of ultrasound
# the fordom and pathology
# mass was and bio tissue cancer disease strain
# the of for tissue and sterileaseache mass masses defect cancererus
# heart and
# heart counts count needle pen celltom was the without pending cancer
# no counts cell cells nodes the and
# an the for tumor
# an the tumor cancer and pathologyiology sterilease source defectnosis
# heart is cell cellsemco
# ----------18----------
# preparation of specimen, manual
# ---------------------
# and caseotti the specimenificeisioncision
# a of and the to [PAD]hesisific refer
# the and [PAD] dental case sterile pathology condition
# nolang proceeding proceed of and or was were are condition conditionsicia biorsa
# this and the specimen by microscopeps limits condition
# and isram
# no without pending specimen dental pathology and was were gall casemp pad
# an caseotti infection sci limits was or without theificeision pad and
# no or infection proceed projections was isram and scissorsision pad defect caseili
# this forpal and the wasram defect pathology dr sterile condition
# ----------19----------
# aspiration and/or injection of major joint or joint capsule with recording and reporting using ultrasound guidance
# ---------------------
# an was echo exam and or pe were areiciaica the joint
# all were areramlang [PAD] joint abs guidance without or pending placement
# no and of were [PAD] applied [PAD] effort attempting placement hem im dia
# general and or exam was hem rev abs the without
# the pad and or prep cement carp a
# the pad prop were injection andilaileilplp was seal guidance placement
# no induction sponge tear [PAD] ofillaiculargnanilmary the joint bilateral
# an and or wereiciaicoigosis waslangili the jointromuter
# and the weremal liga nauseaalicalcial
# a and of were prep as induction sponge rev abs guidance the jointel pad
# ----------20----------
# injection of substance into spinal canal of lower back or sacrum using imaging guidance
# ---------------------
# neck or using was exam the without examination bo spine [PAD] sounds nasalision cord
# anressionic signsc without sac needle administeredscope stimulatedal ortri
# neck or exam
# this fiber tunnel without sac exam and was or cordci gallrsa the spine
# thisile premum was trialromusaulla without
# this fiber cord cords tear shoulder was echo tunnel chamber transverse the spine
#
# an deco [PAD] sounds using wascard or without exam the spine
# no without wereramic obstructionrom or pendinglip the
# a injection was nerve cord and or bladderpon absrom
# ----------21----------
# injections of anesthetic and/or steroid drug into lower or sacral spine nerve root using imaging guidance
# ---------------------
# general anress
# deep wereboltro electro through vialangili [PAD] applied
# an a and injected injection electro wereicia submp oraneous
# nolang [PAD] also electrode using use or and
# after or with nerve [PAD] alsoioicoiol [PAD] of distal shoulder
# general the and induced injection induction tip an wascard orratedhc bilaterall
# the an and
# deep and wasococa [PAD]bra anress [PAD] aden pendingorolin
# general were phaine [PAD] thenorarine and or exam pendingor [PAD] operative
# no induction ph diaheastaticmity injection induced
# ----------22----------
# injections of upper or middle spine facet joint using imaging guidance
# ---------------------
# an was trialtra cervical and spine the or bone fracture jointsco transverse
# nooh fracture acute compression injectionila right spine bone bones and case external without
# deep a occasional frequent and or exam examination pending artery nerve tear spine joints
# neck wasllar fracture cp [PAD]scoaco or ste amp
# a of and were trialinen spa the without side or pe
# no and waslangmoral [PAD] cervical
# this ultrasound the and were injection abs rev correct fracture fracturesuter joint spine
# neck
# no and was echo corona headache pendingyedchia shoulder
# a occasional of and injected scalp using the
# ----------23----------
# injections of lower or sacral spine facet joint using imaging guidance
# ---------------------
# the and wascard [PAD] spine
# a induction deco [PAD] applied approach approached weremal
# neck scalp ofbri [PAD] membrane hardware the a posterior and wasram [PAD]mb
# nooid scalp usingauruter and waslanglal ce vic spine region
# this facial syndrome with and aressedit the spine jointscoacoco fracture
# the fracture acutealral radial
# this facial of approach weredine fe fafa and the kit joint spine
# nooidroids nerve tearmity needler right region regions distal posterior
# an were areral the to aent and
# noano and were are cuff spine was the fracture gelsal transverse [PAD] image
# ----------24----------
# destruction of lower or sacral spinal facet joint nerves using imaging guidance
# ---------------------
# the of and labumus was joint spine pathology surgeon microscope
# this of peural and wereular inter
# and wasram pad gallrot the fracture fractures spine foldmbmic joint
# neck
# the and patent tunnel nerve [PAD] spine fracture fractures pathology reconstructionry
# the bladder and trialtor
# an the and were demonstrated disc disk spine lid joint compressionution [PAD] internal
# the and patent [PAD] spine fracture clamped pendingiac tunnel or pe pad nasal
# the and wascard spine [PAD] range or [PAD] internal pending [PAD] of without no
# and was nerve nasal werellarraltal
# ----------25----------
# destruction of lower or sacral spinal facet joint nerves with imaging guidance
# ---------------------
# an and or patentx without border wall nerve artery
# an deco [PAD] internalural and pathology spine fracture transverse longitudinalus wasllarmb
# a and were demonstrated demonstrate demonstratingicus the fracture gel
# the and patent waslangmoral vic scalp without invasionoid spine
# an the of tearor nerve joint
# the supplying inducedural or and pending [PAD] of spine
# a of trialthy without was and theusnos defect joint
# neck the were demonstrated cad injectionsto and without spine
# neck and wereilla needle joint bilateral
# neck wall nerve joint transverse longitudinal and wereicia defect cadochrom spine without
# ----------26----------
# moderate sedation services by physician also performing a procedure, patient 5 years of age or older, first 15 minutes
# ---------------------
# noulo ex [PAD] and weremaliter cordstignanges bladder ste sh
# anressedress and exam a induction bladder lax was lid pendingici conditionmpt
# an was and infection medrh or exam the distal
# an and is prep the
# heart waslangrot and or ste dilsti [PAD] yearsmal pad [PAD] induced
# the and wasoc indlanglad s an
# thiscard card hemromramformmal distal or without no abdominal
# the for ratio and waslang
# the and of exam distal posterior anressed [PAD] or was is induction con wire
# after and wasoc [PAD] preceded cord aed ste pending [PAD] sh yearsmal
# ----------27----------
# new patient office or other outpatient visit, typically 45 minutes
# ---------------------
# thisjectry and was prep repeat or
# the exam a to and isramlip pending
# thisject anressediva to the and
# general anressrum was grafystchy or without pendingeri [PAD] full and
# this rev wascard and sterile the without
# the on and issal repeat or [PAD] week year condition vital criticalificeus
# general orcardus is exam the waslip and
# his for dim [PAD] or and sterile defecty surgery surgeon cure
# the and forcard cardage or
# nooid cure day year week weeksmal and condition [PAD]vu or
# ----------28----------
# new patient office or other outpatient visit, typically 60 minutes
# ---------------------
# anus wascard condition repeat or and the without sterile
# a per wasmp hemromomy the without exam condition conditions otherwise fracture prior
# thisific inductionstaticzation the and condition conditions
# thiscardage em or graf ste pending post the and
# the for induction [PAD] year or condition repair mel and was iscard card
# general or withoutlam
# this induction suite malepati anressus years or and pending
# nooid cortexogy to or cure was is prep shave shaved shoulder shouldersy
# general and the this repeat forcard [PAD] to or distal conditionme
# hiscard card [PAD] year day pupil wasram and pending
# ----------29----------
# established patient office or other outpatient visit, typically 15 minutes
# ---------------------
# thecard and or whether physician anressedressry rev dr distal shoulder was
# his and islang or exam
# no induction arrest withior
# no premature year suite conference this induction fuss anress [PAD] of medbetint
# a induction pendingioricia on anilivatiuliuti and distal
# a induction return were prep pending
# the and conditionup [PAD] of para bion yearsmate ref replacement 200 250
# an was and trialusa [PAD] interrupted no diauter [PAD]lic theificeification
# general an or exam was grafstation approximately suiteusa yearsmate pendingeri kg
# no inductioninenrade fracture fracturesyedioriacurationus and pending [PAD]lic
# ----------30----------
# established patient office or other outpatient, visit typically 25 minutes
# ---------------------
# thisific in med is am to an wasosta rotation pending [PAD]inenlen
# the in repeat and sterile condition pending today drain [PAD]gram
# his for card was isram pad nasal the sterile necessary blade pd im pending
# general a dim or without was prep repeat the sterile
# general or patent pending branch branchesgul the a nursing sterile and condition vitaltour
# heart wascard anressedress and
# a induction follow isic obstruction [PAD] of sterile without condition buuf and pending
# general or patent and wascard
# noulo cat diadiainen suite [PAD] to condition bu sterile
# general an was hem flush flushed flushing overnight the and pendinglip or condition conditions
# ----------31----------
# cervical or vaginal cancer screening; pelvic and clinical breast examination
# ---------------------
# neck lace versus are were prostate breast nipple scissors dr and case tissue tissues or
# the of exam examination and sterilease testiesles or bladder prostate correctal
# neck or exam and microscopegnandinedincin needle correct prostate pendinghora dr
# heart wereiciastatic [PAD] instrumentation confirmation thyroid without examination and scissors or microscope bio
# a on and exam the wereillacci or prostate pendingstatic defect spine bio
# all was and or peioldinedenl abdomenuter the exam pendingoid
# all of prostate bladder or and sterile
# no prostate bladder correct tissue and implant werellarl cervical
# no bladder correct cervicalcci and prostate thyroidl abdomen
# no prostate bladder ang or and implant pe
# ----------32----------
# screening papanicolaou smear; obtaining, preparing and conveyance of cervical or vaginal smear to laboratory
# ---------------------
# a sponge [PAD] or were areram and wasusa
# the pad tip and prep were [PAD] skin wasram
# a of werellar using wasram or andgnan pending awaitic
# nonal and trialthy wereicia or was hemstatic [PAD] to
# a for denies denyings withoutic werehyl and
# the and wasoc hem [PAD] or weremary cervical pending insertion without
# the bladder weremar and or exam
# this of weredinetineulouama or exam the sterileuter [PAD]lana
# and isusaum was galloc [PAD] skin sci
# a and of lab weremal pad hem [PAD] to wascard bladdertory
# ----------33----------
# new patient office or other outpatient visit, typically 20 minutes
# ---------------------
# the to aurationisionesthesia and conditioncoat bunlip shoulder [PAD]vdime
# no induction suite cat electro hyperpherlip pending overnight 200 site or yearsmal
# general and waslang [PAD] time clockwise or condition adjustment
# this await
# no exam the and or was prep
# hisquetilla induction arrestcard distal
# auppatient anressedressus the was and without or rate region regions
# this await continuation anressedress was grafyst [PAD] schedule 200 250 100 site
# his prep
# thecard and is card or sterile defect
# ----------34----------
# established patient office or other outpatient visit, typically 10 minutes
# ---------------------
# auration or ste was sterile conditionmalifice
# thisificupdownback theressedressureing condition [PAD]nch
# anress [PAD] to sterile wasoc or distal size without condition conditionsifice shoulder
# his and was is prep pendingioriacurationage surgery medicine therapy or bun
# thiscard and or exam theurationisionesthesia dr condition
# this induction return returns failure pending [PAD] distal
# theurationage hyper schedule scheduled replacement replacements was and
# hiscard suite roomnea was card hem [PAD] or and sterileuter consent
# this rev and or exam the conditionusion reason wasrp [PAD] timetime pending
# anressedphy to was is or anymp and
# ----------35----------
# removal of impact ear wax, one ear
# ---------------------
# this sponge gum noyle eye the sterile [PAD] rubber
# was pad remove tip and or gum
# the to wasoc and [PAD] phision scalp positionness
# an wereicia pole the and
# the was were remaining of and
# noano and patent removed removing shoulder eye nasal the
# the of pad and waslang
# a cap [PAD] of fracture ligament tooth was an eye lens aperture nasalifice
# the for reduction and was nerve tooth eye lens
# all removal removed remove without pending bun and
# ----------36----------
# automated urinalysis test
# ---------------------
#
# nostatic bladder wasic without with and sterile defect pathology saline condition drison
# the for transplant and graf
# an was and or drained bladderponturisonicia scissors
# the and or drained drain draining
# the was sterileuresies failureysisuter or graf limits
# heart counts bladder the sterileures correct hyperry and condition mayocision diet irrigation
# anressry the drained saline wasram sterile pathology [PAD] [PAD]ratedration
# a bladderry waslang
# this bladder and wasram the
# ----------37----------
# hemoglobin a1c level
# ---------------------
# an the to for countsiessursurery and or ratease coa tri
# the ofismp at c gpathyfusionco bioc or andtin
# theic signs isram
# heart wasobgm
# heart is echo fusion6oidtosisfor tusionudingudeuded [PAD] q
# heart and or raoghg [PAD] tglc notedpathy [PAD] rate c
# wasicsur [PAD] heartry noted
# analhal [PAD]oghgglry and or coaase heart thepres
# a positivery forglgus
# ascusnosglguspus the and
# ----------38----------
# vaccine for influenza for injection into muscle
# ---------------------
# and for cough the anressedpress vic guidance was gall incrcleco diabetes
# anress and the forolin [PAD] of
# an a the and was cl fortou
# was for colon coli and werellar
# the was gall of trialthy and or infection antibioticsase heart
# heart is injection needle was trialthy without pending dr
# and was gall for hardened weregul the an
# an waslangolin and or infection injection forzer the
# an the and trial infectionker
# wastail abdominal bladder without the hardened
# ----------39----------
# pneumococcal vaccine for injection into muscle
# ---------------------
# hecardco hemyll aile ear andgnan etcca
# thecard cardraine was andiligul
# anressal dilyeectionisiondation the and
# ascc injection in aden and was
# thisaco waslangl leth [PAD] native
# this chronic [PAD]inesur c ca and or scissors syndrome wasccicinryl
# acardage [PAD] of andiliila the scissorscci
# an aalcal or wereguiined and
# noani astiotti theressedresspress conditionccicin [PAD]emia cancer
# wascard c asti
# ----------40----------
# vaccine for pneumococcal polysaccharide for injection beneath the skin or into muscle, patient 2 years or older
# ---------------------
# acard of lable peuane s and or fi brobro
# aicrcrr [PAD]gramliplitheasis and wascard or pe
# a with wereiciaicocci [PAD] wasoc and ortritre ceeca
# aicalyl [PAD] of ci
# an wascard or and [PAD] adendunlit breast the aile injection injected
# a occasional [PAD] thenrom con oboblbllar dillcus washyl
# noanococu cu ge anani t dilnch and bro aicular
# heart acardisic incccumatic waspls mayootti andsti
# anressressed catum wasobmalmblllin and infection infections lu
# an wasalalaegad injectionpi weredinedinllin pal orsti
# ----------41----------
# routine ekg using at least 12 leads including interpretation and report
# ---------------------
# all and iscard cards gallo
# a for procedure procedures exam and were correct sponge the without or rates
# a and
# no and the of examination to wasiciaaminavary or
# and acard ofrum foroto an was hemrom
# and or ofrum for count counts [PAD] qplexusnosnosis
# and the ofrum or an pad [PAD] q cpo without waslip ek
# the and [PAD] ofagealhri anressedress [PAD]vpathyiesrum
# a sponge fever the and [PAD] performedromusaus an [PAD] of distal
# the astra trialthy chill and correct proper adequate alternatives options limitsage
# ----------42----------
# established patient office or other outpatient, visit typically 40 minutes
# ---------------------
# the and or without takeoff wasram
# a induction arrest in graf condition conditionsid med sterileures
# a post followal poster or and sterile
# the for cardcard or sterile
# the to isram without [PAD] weeklip pending branch 200 250
# this for pending today or without card [PAD] week
# his and or ste isram pending [PAD] weekus was card ne im without
# thecard distal sterileus and lab laboratory pending [PAD] of med nasalifice was
# noinal and is exam waslip without sterile conditionuf fashionus or pending
# this ultrasound wascard distal or exam condition conditions indmp um ste reason induction
# ----------43----------
# administration of influenza virus vaccine
# ---------------------
# and the forwire was weredine without pendingeri diabetes [PAD] stimulated
# a with for trial infection antibiotics
# general or of infectionbiotic antibiotics and without the sterile breath
# general an sterile of infection infections dr guidance the was and respiratory pending or induced
# the bladder and was induced without infection fever
# heart counts diabetes antibiotics [PAD]inen
# the and were ares
# the and of disease respiratory was infection infections antibiotics dr condition conditions injection injectedcin
# general the a trialusaush and
# heart
# ----------44----------
# administration of pneumococcal vaccine
# ---------------------
# a with incc calstilit lit theiliviliusaglyl
# this fi chronic [PAD] cesarepathy diabetes tuberculosis condition conditionsabe
# aup up and trialthyiol [PAD] of induced induce [PAD]ov c surgery
#
# an and of ciccialhallitlot
# aup of ci wasocvacuinlitili [PAD]lkeainecingnan
# this chroniccci mm cm injectionc astirtiilivatil and was
# general and [PAD] of inccci cialcal theilivatiitis [PAD] induced
# an was and trialusa
# general anccisti
# ----------45----------
# annual wellness visit, includes a personalized prevention plan of service (pps), subsequent visit
# ---------------------
# blood and was hem diagnosticrot
# and were dependent [PAD] of trialdine gallo or cure treatment proceed continuation [PAD] acute
# heart counts counting recommendations advise guidancealhri drisonicia gallo andgnan
# anressrum of exam the care medicine was and
# a with were benefits or repeat repeated and care cho bioicia [PAD]tery
# an and of diabetes arthritis tuberculosis medicine therapy or any anywhere
# the and or prep pig werescoacocin [PAD] statusation diet bleeding infection
# the was infection infections and is informed [PAD]arthochhg size correct priorage
# heart was infection infected or steior [PAD] distal [PAD] prep present of diabetes glucose
# and or repeat of prep the distal care infection treatment treatphy rec rev dr
# ----------46----------
# urinalysis, manual test
# ---------------------
# and bladder ur
# the injection wereiciaificationization pending without and ligauter correct rightema
# heart isram anduteriterctionill renal biobiory without
# noic ligaal ctma or sterile
# no and was padudge
# thiscard
# thisic without equalsuter correct right ur
# heart
# nouter bladder correct renal wasram pad the without
# and ligaal injection weredineden without or scissorsbiory sterile defectcision
# ----------47----------
# transitional care management services, moderately complexity, requiring face-to-face visits within 14 days of discharge
# ---------------------
# the as to wasmp sepsse and sterile
# general or withoutic galloma waslip pendingior the and conditionmal pad
# the to an care diagnostics gallo or without hem limb
# the care management and to sterile was prem guidance without [PAD]ctableumatic nasal condition
# this and wasoc [PAD] system clocksco proceeding proceed continue continuing or exam
# after and were benefits wasyle referere the pending without [PAD] system 200
# the of diabetes medicaltour wereiciaic per pending given nasal and
# general were dependentses and was prep [PAD] or pendingioriac nasal without
# after andmalitermp
# a with the to anressus and sterile condition dependentmp pa
# ----------48----------
# transitional care management services, highly complexity, requiring face-to-face visits within 7 days of discharge
# ---------------------
# after and to thealisal repeat was wereilla gallo
# no care and sterile
# general a and was trialtionionures [PAD] or bun bio limits saline
# a after and trialtiontions res refeds diacted su
# the for benefits and ormal pending refer to wasoc
# this bro and or to waslangmoral
# the for benefitss nasal gum was gallo and oraneousatedativeiculartal
# and wereilla to the
# after were are to anressus and withouticicaltiontionsion cp
# an isic and trial home respiratory pendingiormal fracture res refificeici
# ----------49----------
# initial preventive physical examination; face-to-face visit, services limited to new beneficiary during the first 12 months of medicare enrollment
# ---------------------
# prior and trialusailla
# general weregnanlangring without pendingipep and or exam the condition conditions
# the were sponge benefitsy hyperstational repeat conditioniciaior [PAD] ofring
# the ofyleinen dentalesgit was and or whetheribacior condition
# noic of physician pregnant andile [PAD] to the wascard hem rateal
# general and or exam thelit lit [PAD] alternatives risks futuretis infection infected
# prior the for pending [PAD] an and to conditionior s
# after the to orialcard an sterile and
# the ofiscard card to and
# the and wascard pad refer referred with anressedialaltal hem
# ----------50----------
# annual wellness visit; includes a personalized prevention plan of service (pps), initial visit
# ---------------------
# nolangrot with and wasram fracture acute position positionsrc
# a for report views syndromephobiamp and care bioyl or proceed
# an were trialusauflitlip the and was proceed continuation continue correct views
# no care infection with diabetes antibiotics years timesmal condition repeat laceufcin needle
# the was and proceed proceedingco hemdine pd [PAD] font [PAD] statusalsti
# no and or exam examination wasoc induction proceed proceeding pendingistagrade nausea
# blood and infection informed notified 59 waslip or [PAD] cook prior
# the wereicia [PAD] and waslang care infectionemema rulesti or cure
# and the to or proceed
# a with anani the to or prep cord
# ----------51----------
# aspiration of bladder with insertion of bladder tube to skin surface
# ---------------------
# neck bladdercre respiratory wall apron mor saline or controlled without was hem
# thiscard and bladder sheath
# the fortratric and or bladder pending pad without
# nonal of inc abs rev and was the
# heart
# an bladder of and wasram pending [PAD] carried the without
# deep was of trial wire and bladder
# the bladder [PAD] induced coli and lab [PAD] carried without or patent defect
# the of sheath bladder with [PAD]gingldingrti
# aicular and inc induction [PAD] carried burdency sheath vein without
# ----------52----------
# bladder irrigation and/or instillation
# ---------------------
# or without of air and waslangili the sterileuresurery conditiony
# and or
# the as and were colonifice or
# an wasmp and the or [PAD] irrigation bladder [PAD]ciency [PAD] breath
# andtoryer the bladder
# a and of inc abs
# and or werellarstini
# this with and was weremp or [PAD] irrigation the bladder correct
# the supplyingnation or and
# this bladder or withoutic incrom the and sterileingsf condition conditionstou
# ----------53----------
# insertion of temporary bladder catheter
# ---------------------
# the bladder [PAD] of position positions placement insertion prop or and pending [PAD] functional prostate
# the positionhesionencyer noent defect sewing and bladder
# insertion the of position positioning positions placementation was bladder
# the to bladderpon cat
# insertion and bladder position sheath scalpation the was indremificeisioncisioncise
# no pad bladder functionlumlip was placement insertionage without and position enlargedtor
# a placement inserted waslangrill the and or bladder
# right is trialthy wall and
# no cuff ph cat bladder inflated anile injection position condition [PAD]lva placement insertion
# an a bladder [PAD]het right was cap tipert and position positions placement removal
# ----------54----------
# insertion of indwelling bladder catheter
# ---------------------
# the to bladder using usedingog was lab
# a placementrum was echoator and or
# an the pad of injection using was bladder transax
# an and wasoc of lump bladder [PAD] bypass without
# a catatoration of sheath bladder the
# no cationmentingiom insertion inserted inflated an defectilscoano ur
# nooid bladder syationstf the and without [PAD] triple doublertinenino
# the on wascard and wereiga bladder correct scalp
# a cat needle pen of and were bladder
# thetail bladder catationator
# ----------55----------
# removal of skin suture with change of bladder tube
# ---------------------
# the and bladder [PAD] removal without obstruction artery mass
# a supplyingmp sep and without border wall or bladderponcum bleeding flowano
# thisicular the of cuffalhal position pro insertion extraction nouration defect solution
# the to bladder
# a with was hem nylon of exam and
# an the of pad waslang
# a of sheath bodyottiossa ligament the anressedvd and defect
# a induction [PAD]zia [PAD]ao
# this stripsng and obstruction artery arteries node the defectyce a placement insertion
# was and the of exam pending pad pads remove bladder bleeding bleed
# ----------56----------
# electronic assessment of bladder emptying
# ---------------------
# the for counts count [PAD]tia bladderry
# the and waslangrillomy condition
# an waslangrom
# and the bladder [PAD] inspected withoutage condition
# a for testuter and or sterile the was laboratory lab pending
# a for exam the and or sterileuter shave of limits condition correct
# no and wereicia [PAD] bladder the correct
# and
# no and or the [PAD] of examuteriter limits diet bladder
# the for air and trialthy condition
# ----------57----------
# ultrasound measurement of bladder capacity after voiding
# ---------------------
# this ultrasounduter was needle administereder and positionhesionnarermirti a abdominal
# blood were sponge bladdertoryers and was the sterile necessary
# this ultrasound mri using wereram
# the bladder [PAD]static mass and was labing guidance
# the of stool were are function stone and
# heart the pad
# the pad was wereicia bladderpon [PAD]oolificeing lab caseotti and
# this injection bladder sy noted replacementtionation and position positioning resase [PAD] test
# a placement needle achieved accomplished [PAD] and the pending or defectuter for ratio
# blood bladderer no abdominal ct field wall guidance position
# ----------58----------
# diagnostic examination of the bladder and bladder canal (urethra) using an endoscope
# ---------------------
# no exam and wasramomy bladder urine or peemalang [PAD] of distal
# general and the bladder [PAD]graphicgraphs [PAD]trocoema
# general was were tube tubes
# a examination the and were bladder
# the bladder or hem [PAD]gram
# right wasramlang [PAD]graphic or and the
# thisumatic of examination and sterileuter a bladder [PAD]graphic without was wereicia
# the and of pe hemnen were bladder
# the ofisicooidoids bladder [PAD]trotrytric quadrant bleeding ce lateral
# nolang
# ----------59----------
# biopsy of the bladder using an endoscope
# ---------------------
# heart and weresco bioromolinoki the bladder
# an was echo hem lace drainage transverse the
# noic injection inosisysis the and sterile pathologyase [PAD]tumemauter
# aic examination the to wasost
# blood the and incusionationsatedatingation
# the for injection and a hemxtisioniterctioncted was paduter bladder
# thisile exam and was [PAD] bladder
# the pad and was exam of bioeth or without
# blood and was hem [PAD] bladder
# the to a exam and
# ----------60----------
# destruction and/or removal of (0.5 to 2.0 centimeters) small growths of the bladder using an endoscope
# ---------------------
# no bladder using inflated fracture oro and or [PAD] ofpore pad scan [PAD] size
# this ultrasound of and was cl weremal distal size any padudge the microscope
# and bladder using used incromuloilla can hem silkginaluter or enlarged
# and wasmal of incrrrom or [PAD] liver distal bladder urine size without
# blood the and ofome tube tubes was or exam examination
# no and was hem [PAD]hesisysis the anress os ras
# the was were tubemalma
# the pad were [PAD] to or bladder gland ofici and
# the as bladder using inccccal and weremalmbmp ph hemrti
# and wasram infection weremallip pendingic ofof using obe the
# ----------61----------
# removal of foreign body, stone, or stent from bladder canal (urethra) or bladder using an endoscope
# ---------------------
# the foricoic using beingram padudge or without exam and
# and or bladder function stone stones
# no bladder using utilizing utilized a injection injectedjectrot wasoc ur or pe
# no bladder
# no inductionstatichr [PAD] ur using bladder or without gel [PAD] liver
# blood or bladderls and implant without were dependent prep lab
# an a mayo or and without with waslangrom bladder
# an is or bladder syrom [PAD] urine and was lid bun bio urrh
# a and or without with anressry wasram pad the exam
# thisic bladder with without and or pe cl waslangrot
# ----------62----------
# insertion of stent in urinary duct (ureter) using an endoscope
# ---------------------
# anry inibiol [PAD] using the wasramlip
# an isry the bladder ur stecoe
# this guide wasocome implant using
# right was echo revisiontor urr the a supplying and graf sheath bladder
# nooid [PAD]troema [PAD] system and orecauter the distal
# right and lab
# right wasramry and [PAD]graphic the [PAD]pinglangiacificeisioncision
# thisic flowflow and werelang ang ur without was nodilakarlip
# anressed with a and weresco mayouter waslip pending [PAD] ur or
# using andmal ur or steral distal sterileuter hemrtiilaiac sac
# ----------63----------
# crushing of stone in urinary duct (ureter) with stent using an endoscope
# ---------------------
# the and wereramoid [PAD] of tons
# nolang ur or ste wasici and [PAD] of lumpiliilail
# no and ligalang [PAD] ur ste using was weremal blade [PAD] ce vic
# the usingcard card bladder orram and
# nooidoids hemeth and liga bro wasiom ur steuter [PAD] using
# nolanglanialurgiac [PAD] ur wasiomilailla [PAD]eca vic
# was pad and injected bladder usinguter or weremalmun ur injectionfusion the
# noohromic injection
# a of and coliosis liga nausea bleeding bleeduter
# using incic irtionical [PAD]eca or exam and waslang [PAD] use
# ----------64----------
# insertion of implant in bladder canal (urethra) within prostate gland using an endoscope
# ---------------------
# thiscard card of and was implant without the bladder function phuration
# this of pe sep sheath cat bladder
# right the and lab [PAD]clec was wereilla [PAD]rencery sterile
# the of and lab insertion inserted insertvertcr hemyly prostate bladder ur
# using incromiomlocklalsurscoicoylhylnia placement
# anile ph chhromy a end was bladder hydra the without or exam
# the using insertedisicular
# this bladder
# the of lab ur weresto tissuemal pad was is implant coli [PAD] and
# a bladder and exam of lab was peuter or without using
# ----------65----------
# laser vaporization of prostate including control of bleeding using an endoscope
# ---------------------
# the bladderpongas hemrti a withostaase injectionuter vicvac scalp
# the for patenter wasscoicoacouter
# a of surgical using wasramlang and
# heart waslangrot werescomal pending insertion extraction extracted remove
# the and were areic without with prostate pole
# anressalural
# thisaco and ultrasound forome using was the [PAD] prostate poleuter
# an wasram bioat the to
# using anani r the and or was sterileuter shave patch [PAD] applied removal
# nooidpsy [PAD] done and wasram the
# ----------66----------
# biopsy of prostate gland
# ---------------------
# the of and lab laboratory test testing correct trans biovie ct
# no prostate breast bladder correct ctmaema or and pending moleileilscia
# mass notedal test the
# heart of sperm [PAD] test
# biobio was tumor cancer bladder pending
#
# the prostate bladder
# the and was gallral ct wax tissue defectil cancer pathology medicine dr condition
# mass were includingrum the sterile and bio prostate trans bladderpon [PAD] test scalp
# a test testingral ctiobo bo melal bio poly placement insertion prostate
# ----------67----------
# imaging of urinary tract
# ---------------------
# theicular of trialthyry
# bloodalalavasvertry
# thisalral andrum
# thisic obstructionromrumalsureterer the bleeding infectiontisnos
# anryalsurkar dia and or bleedingemia
# anressalnalnous the and bladder transrot bleeding infectiontisrisrr
# nolangrot and orrialry in aden ligatristista
# nolangrum the bladderry
# analnalic incromrot bleeding infectionscope and waslang
# noic injection injectedalry inomeimema and lab ur bioiot
# ----------68----------
# ultrasound of rectum
# ---------------------
# this and wasoc ur the sterile defectilscia [PAD]erus abdominal abdomen pathology
# mass waslangema [PAD]ram pad ligaal ct scan and enlarged bleeding
# this and waslang liga paduter the [PAD]ewyst
# an was and ultrasound for examination bleeding the sterileaseilleillaicoifice
# an the to or and was lab pending swelling [PAD]ew
# nonal the and waslangelal [PAD] ultrasound
# ct and or exam [PAD]tum the bleeding
# ananiano to the
# anressedrumal examination the and pathology sterile
# a res forrum the without and defectilscia quadrant abdominal scissors shave
# ----------69----------
# ultrasonic guidance imaging supervision and interpretation for insertion of needle
# ---------------------
# an and the forome placement
# and wereicia pending revision cavity
# nooidoids induction placement obtained guidance ct and
# this of counsel pending vibri
# an waslang and microscope lens eyeisioncisioncise
# the placement obtained approach fracture fractures await [PAD]tensision guidance and pendingeri without
# the and was needle wire tube guidance or microscope pending
# a and was hem lace drainage transverse the
# the guide were are manual guidance placement tip
# general a counsel approach was were placement [PAD]copic guidance and lab caseots
# ----------70----------
# injection beneath the skin or into muscle for therapy, diagnosis, or prevention
# ---------------------
# and respiratory isram orratedration
# the care or and
# thisificoid respiratory oral prop was and infection antibiotics
# the for respiratory or cuffus was and infection antibiotics
# an the to or microscope and fracture fatiguerp without infection infectionsbio biorom
# nolangraine or weregnan etc lace
# the and were dependentse microscope bio [PAD] of or flu wasram dialization
# and or refer referredgical [PAD]ryn [PAD] of injuries injuryitisicicin
# the and for injection injected biting bite [PAD] of nausea or sterile pathology therapy surgery
# the pad induced em [PAD] and or without breath
# ----------71----------
# new patient office or other outpatient visit, typically 30 minutes
# ---------------------
# an wascard [PAD] admission condition conditionssis and pending revisiony
# this to and repeat was is prep the
# a with the and was card distal shoulder [PAD]ageemiaemi
# this induction suite roomneaema is tailor was and
# the for induction [PAD] replacement or sterile pathology
# a post the to an sterile was prep time condition repeat
# heart anressed cat denies denying denied [PAD] time repeat wasoticuter the condition
# the for card stestation [PAD] and
# an a exam the was isram and or without
# no denies or grafus wasram and condition bun without [PAD] week daysid
# ----------72----------
# initial hospital inpatient care, typically 50 minutes per day
# ---------------------
# a post distal size sized pending branch bladeinaage vitaminbon fracture antibiotics medicine
# heartstation repeat and ultrasound theressedressuresuration syndrome was stitch patch nasal
# this for induction
# a per and is repeatuter to was care medicine nurse dr ct gauge an
# the care acute for linear suiteillaitis conditionase trico region
# this inudge was hem [PAD] pre pending or rate suite
# an the a general or wastail
# heart is card ne septng pending [PAD] pre long longer
# this ultrasound
# the careage with and
# ----------73----------
# leuprolide acetate (for depot suspension), 7.5 mg
# ---------------------
# the and weremp amplip atin gallocoel or vicus
# a with the anressedlugul was is fix
# noalhal waslanglu the and sterile defectyedy nasal
# anress catyleyl leth the wasmp cc injection
# an and wasocacin the injection induced induceili
# the was isubrom [PAD]lor and or bun steuter
# the and to washylne or gel
# this injection injectedylhylne was noddinol l 0 no any without
# thisyle ananini was cc injection
# a on wereocacin wasyl [PAD] hydroam or
# ----------74----------
# harvest of veins for coronary artery bypass procedure using an endoscope
# ---------------------
# a and wereilla corona
# a supplyingicc corona and coliiac [PAD] artery thembomp or ste
# nonalalral and sterile defectnosisage choilla corona the without or
# an the and were areic artery arterialmoral acardage intrauter
# acard the of arteries was card corona
# anressedit the wereks corona was and liga bunlipctedcting
# was nodalhal sheath artery massnal and
# a and wasocvac corona pendingeri diabetes
# this bro anress and liga corona a general ortritre con
# heart acard and liga [PAD] performed usinguter
# ----------75----------
# heart artery bypass to repair one artery
# ---------------------
# a supplying cat pulmonary the and was fusion limits bypass bunisonision liga pending
# a heart was fusion corona cat artery arterial radial and graf needle
# blood and a renal sheath artery arteriesmoral bypass the
# the and was hem renal pending artery arterial arteries vic joint bilateral defect pathology fi
# anressedress and graf
# a supplyingulo
# heart was and artery arteries
# the renal heart counts failure pending bleeding artery mass
# a and is fusion corona the fracture jointelal scissors vicivevas
# the supplying patent was component graf radial and artery
# ----------76----------
# interpretation and report of heart ultrasound examination using esophageal probe
# ---------------------
# thiscard cardsral and wereiciaificationization
# thisic wereiciaificationulation the and or measuringisionoc pending insertion was
# the ofageren without and wereillaille placement insertionoh or pendingusa
# the weresto and hem [PAD] viapingpit placement prep scan scanningromomy
# a with and was exam conditionaciacoc
# heart the examination to needle pen [PAD] biooidoidsomyiesalral and
# bloodal ultrasound forical examination weremal condition conditionsabe
# right was exam ultrasound examination and were aremaltal hem [PAD]graphic pending
# a of trialalsurscopic ct catcat hemromusa case flu the
# blood ctioiccopic bypass or exam and
# ----------77----------
# anesthesia for lens surgery
# ---------------------
# the injection injected bladder was and
# a for injection injected and or microscope pathologyiology
# general and the wasoc aniliilola
# was gall ligaal approach position were injection pun
# ananial injection forjun and the limitsage condition conditionsificationify defect
# was and pathology medicine
# the was islangolinmunisionesthesia pathologyiologytology fracture radiusness fatigue
# the bladder
# general were injectionfusiontag vic guidanceal ct
# an and the to sterile pathology
# ----------78----------
# respiratory inhaled pressure or nonpressure treatment to relieve airway obstruction or for sputum specimen
# ---------------------
# an was induction reduction respiratory or [PAD] of and nasal the pending [PAD] forotic
# anressedup and wereulo
# the and wasoc insertion induced using or noanoonologram
# neck and liga respiratory or exam the to wascard [PAD]ulsuterpati coli
# general and patent was inductiondicationionalical [PAD]int paduter
# thiscard [PAD] pulmonary and wasram solution pending [PAD] skin nasal
# general wereulo engusginccialhalhala and infectionosistis
# the and was pad repeat for injectiontoryionment conditionpiration [PAD] pressure or
# thisileilyle eye weremaltal injectionmbgnouter or was si
# no beadsl respiratory injectionfusion or and [PAD] cavacuter
# ----------79----------
# albuterol, up to 2.5 mg and ipratropium bromide, up to 0.5 mg, fda-approved final product, non-compounded, administered through dme
# ---------------------
# the to wasoca and butmal bioep ofyle a injected induced
# the and wasocmal mayo [PAD] of injectionlllin anress [PAD]rence
# aic with and wascardald anressedressiontionation ph
# a forglillaylemalm or wasram bunhyl and flu
# was and or mor ca withdinellin anressedionne the without for
# the an wasocrat or without with and inducedmalm
# thisic injection withd theedlybidhyliontion
# he and forylen the a injection induced induction gallo
# a and
# an or wasramlangrot a nausea the and
# ----------80----------
# aspiration and/or injection of large joint or joint capsule
# ---------------------
# thisicular and implant dental joint spine cad compression the was nod fracture fractured
# an a injection foric without were placement wasram fracture nylon and sterile
# and
# total nerve and injectedmin dil
# anileila and [PAD] or
# the fortrapiration [PAD] carp needle was anressedress and jointscoico
# nooh compression [PAD] applied andilailiil joint orile [PAD] without sterile
# an and waslangromrot without exam [PAD] weight size radius
# an and aile [PAD] without with the wasram pad [PAD] fit or induced
# an or weremalsalsti and without wasram pad [PAD] weight joint
# ----------81----------
# prosthetic repair of shoulder joint
# ---------------------
# neck shoulder without motion cart
# no fracture repair tour of and was cap without shoulder spine fold lace scalp defect
# no reduction and inc [PAD]rationrated joint spine bone shoulder defect
# a of for hardened the sterile defect joint shoulder
# chest joint [PAD]ment lace
# chest and lace def fracturecticular joint spine boneness fatigue shoulder or without
# no cuff arm ligament fracture bonement wall and
# general nerve ankle knee tearment abs
# the pad toe ankle ankles scalp [PAD] joint shoulder
# no beads repair knee shoulder spine
# ----------82----------
# extensive removal of shoulder joint tissue using an endoscope
# ---------------------
# the and wascard
# a cap capser incesthesia electro techno limitsl and enlarged instrument instruments using
# anani the to was weresco fracture orouter
# this bro wereram bioeth inc surgical kneeuterutationulation condition conditionsabe
# theanialumaticisionation wastail
# the and was wereillalangoro or withoututive size
# a cap of end anressed [PAD] and without surgery medicine
# this of and wereilla needle bladerol bun waslang liga steution
# a end and
# a using wereilla [PAD] technique the was an
# ----------83----------
# shaving of shoulder bone using an endoscope
# ---------------------
# an wasram pad pads bro a bone bones scalpcututationision fracture fractured
# his of and exam the an tooth teethuter
# the using was echo incfusion and or
# an a capscoico with the and was cord fashion vic needle blade injection
# noulo forome [PAD] a applied needle pen injectionpati shoulder
# this and were exam the to wasram pad
# aanialoc
# neck wascard or pe ligasco scalp of posterior scissors
# the usingingcopicscope scissors was applied cure therapy
# an and a needle was mayoisionoc or
# ----------84----------
# repair of shoulder rotator cuff using an endoscope
# ---------------------
# nolang [PAD] shoulder and orrated
# nooh is exam
# an and wascard card with [PAD] hip [PAD] knee
# the to fracture fracturedct and sterile
# the to and fracture failure failedrti
# a foric compression [PAD] techniqueusnosnosis was lidrom hip shoulder shoulders
# right wastail theome stemba [PAD]pment joint spine defect cad injectionpi
# an the wascard jointc or without limitspment
# an was and inccr phrom footscoacoitoificationifyifierdication
# heart the chronic cuff [PAD] knee elbow
# ----------85----------
# x-ray of shoulder, minimum of 2 views
# ---------------------
# right wastail or without [PAD] and
# the examination wasram hem ratio without equals shoulder
# neck wastail a needle administered doses dose and
# the of examination
# a exam and was examination
# right a capcap and
# nooid hem with was isram bioeth pending or and fracture fractures
# no a of injection and is examination was wereicia foot pad [PAD] full bleeding
# thetail was hemrom [PAD] rangepathymity or without pending revision cr
# chest were exam examination and istail abdominal the distal
# ----------86----------
# x-ray of knee, 3 views
# ---------------------
# no werelangema stitch stitches pending foreign the and or bunison
# thiscardage of and or without
# the to is wasoc or exam condition
# a of and were areicia foot the an
# a on wasram or
# neck isramlip and waslangili condition
# chest or examination and trialusalip the
# a examination exam of pain compression and was
# thistail the a on or and sterile fracture joint foothgifice eye head
# the was needle and [PAD] done position contrast mass
# ----------87----------
# injection, methylprednisolone acetate, 80 mg
# ---------------------
# and wasmpyll a thyroid without withlkey epaine bleeding bleed
# the for injectiondinedenl
# an wasmptaml theressedainetinllin
# the to wascardall and scissorsvatiulilitliplica
# a injection werecci ste amplau and the scissors
# noanoallr wasphine and
# notampds s injectiondinehyl [PAD] of gelbonl
# the tube [PAD]lor and injectedgas
# the and injection prep caionl
# a pertri [PAD] induceddinehyl and was ca
# ----------88----------
# hyaluronan or derivative, gel-one, for intra-articular injection, per dose
# ---------------------
# an or with and repeat weremal mayoinetinedinegul the sterileuter
# thisalhal or and wereglillabonona an microscopelablip flu
# an or and were aremal [PAD] of exam the sterile [PAD]phineision injection
# the and was pad echo nerve arteryic injection injected doses anressedressgul
# the injection with patent were arebintintens and sterileuter
# this for patent and trialthy ccilla [PAD]ine injection injected doses dose the
# this ofbidrom or and waslanglad the an microscope biooid cho
# a with and microscopeal dilgul or the sterileingsur pending
# and or any pad repeat for intraing injection injectedject [PAD] of solution cure
# this ofyle injectionmin
# ----------89----------
# hyaluronan or derivative, monovisc, for intra-articular injection, per dose
# ---------------------
# aic echotrotri administeredl the was and
# he andmalma anani were are injection injected induced stimulatedioco trans
# the and or without geltri solution [PAD] etage [PAD] reduction
# he forodrom [PAD] was and microscopebin injection injected inducedili flu
# aic injectionpi was echo and werellarulo [PAD]amina
# nolangemayl [PAD] et was echo andllin [PAD] reductionuterccicin
# general anressedrit and the to a [PAD]ine injectionfusion vicusnos
# a with anlang
# he for injection
# no and ortritroened aicular of intra was isram solution pending
# ----------90----------
# insertion of needle into vein for collection of blood sample
# ---------------------
# thistail chest mass weremal padudge caprum blade needle guidance
# nooh were dependent correct sheath injection insertion was obtained the without [PAD] collecting artery
# the and a to [PAD] blood artery pending or defect
# general the and inserted insert insertion needle was wereiciaco
# general wascard or exam the care to sterile defect
# no pad was echo
# general was sealrum without the pad pads needle blade ligauteriter [PAD]tia
# heart and the to wascardage [PAD] of microscope defectuter [PAD] full without
# the for trialthymal
# no and of trialthy was needle without the pending [PAD] internal vic
# ----------91----------
# therapeutic exercise to develop strength, endurance, range of motion, and flexibility, each 15 minutes
# ---------------------
# and was motor echoion range [PAD] motiongesgas
# heart waslang andionments the anressedressuresure or
# blood of and were counts aging aingeiesionations painsitis [PAD] range
# heart the to a ref andionles
# noile range maximumnen and orionment
# and of trialnen or anyionations [PAD] rate
# no and were counts countile heart or the care gallo
# blood and to or motor gallo the limitsionment condition conditionsdationrr
# the for muscles muscle was and [PAD] size anressressed bengal condition adjustment or
# the as range include included reflectedtill phionuresationative hyper
# ----------92----------
# therapeutic procedure to re-educate brain-to-nerve-to-muscle function, each 15 minutes
# ---------------------
# an and the wascard card pad
# the and were echo ne [PAD] rate or
# the was trialthyromroplip limitsed to or
# heart was nerve [PAD] rate needle lit [PAD]trogl [PAD] artery the and surgeon
# a injection in trialthy islang
# this bro and or exam aileilscia the limitss
# this to was pad and sterile breath the
# heart and needle ne [PAD] stimulatedase
# a supplying mmic liter diaries ints wasllarllation androm rate
# this guide werelang [PAD] rately the anressus
# ----------93----------
# manual (physical) therapy techniques to 1 or more regions, each 15 minutes
# ---------------------
# noic headache was pad and pains rescum the
# an was echo exam the and distal
# the and were are to a physical for was instructionsc cmhg
# the to for trial were diaries bladderponmos [PAD] and wasrprr years
# an the of trialthy and was echo without condition extendsly or bladder measuring
# all and is arerum or to the anressedbil bio
# the guide guidance or without and pathology therapy [PAD] cm foot toe toes was is
# all the were dependent to a benefits or conditionmpt post and was placement cp
# general were dependentma waslang 250 and pending overnight
# general and to anressed after fracture antibiotics infection mm degrees or size
# ----------94----------
# evaluation of physical therapy, typically 20 minutes
# ---------------------
# the to and wereiciaicoification [PAD]ifice limitsage alternatives dr mm condition
# an was echo exam
# the and wasoc pending given
# anressedrum the andema was condition correct fracture fractures
# the to and was pad
# nolangema replacementtionionment
# general or bladder measuresage and pathology condition
# a ofrumuter foricoco
# the to an and
# this sponge daycoatsisus an limits the
# ----------95----------
# evaluation of physical therapy, typically 30 minutes
# ---------------------
# an a general the and wasocvac [PAD] schedule morning bleeding condition 200 250
# ##ema and or infectionosis the waslangili
# general an the and [PAD] schedule
# anressedressrumuter forpresces wasmprp and shave limits maximum
# noyle replacement rehabilitation was resumed and limits maximum
# nooid sponge dayill and the
# an waslanglal repeatemaosta
# this awaitep wasram bunema
# no and waslang dialonralificologicalologyifice the shave limitsage
# ##ema and the a exam distal care repair sizeage vitaminures
# ----------96----------
# therapeutic activities to improve function, with one-on-one contact between patient and provider, each 15 minutes
# ---------------------
# anressed patient repeat wasram and the [PAD] of problemsmp [PAD] nasal or
# the care to and was cardcard
# no were sponge
# this the and repeat or any anywhere
# after and was pad echo dias or the
# all and wereiciaicoaco the waslang care condition foot or microscope ref
# after was and microscope without or pending [PAD] gallo the care medicine med sterilerbin
# the to were aremal repeat waslang and without shave
# general waslangrot and or without hooktionionures [PAD] distal the care
# all were benefits or and the pad repeat was tailor pending [PAD] nasal
# ----------97----------
# vaccine for influenza for administration into muscle, 0.5 ml dosage
# ---------------------
# a on wereglfan and microscope the this
# this gelbon for ml [PAD] of nausea washylco and
# an the wasram and without chilling nasal
# the pad and trialthy withouts was weregnangl geltrirrsti
# a for injection and was solution heart isram
# and is infectionem l x qbont wascin the bladder
# the bladder [PAD] of gelgl was and or without
# this of microscope gauge or
# and was the of trialpathy injection injectedcin cadiacificeision
# thisificerine a positiveds and sterile defect
# ----------98----------
# ct scan of heart blood vessels and grafts with contrast dye
# ---------------------
# an the was and werescoicia liver
# ct or and were areicia heart count blood corona
# the pad wasramlangotti
# ct blood corona electro or and were ares con the was nod scar
# blood waslang angterol artery arteries biotom without the
# an and sterile breath or hem blood bleeding tissue
# heart and or ste graf liga
# the weremal liga and sterile padudge
# a sponge cap caps or and wereiciaico the sterile breath condition res em
# no ctma wereicia heart was stitch needle and or sterile defectiac
# ----------99----------
# nuclear medicine study of vessels of heart using drugs or exercise multiple studies
# ---------------------
# deep were are corona without [PAD] and pending [PAD] treatment treatty nasal or bladder
# the bladderrum was trial wereilla corona bun and or
# and were are trialthy using utilizing utilized test testing or pending without sterile pathology
# this nod [PAD]genbonma fracture tissue the for surgery operation therapy medicine
# the pad [PAD] testrationion guidance were are cure therapy pathology surgeon microscope dr
# no or and trial test testing using
# thisificerineer and weredinedant pending awaitiacicoification the pad
# deepila heart and needle weremal
# this nod corona [PAD] underwent undergone liver bladder or rigid relaxation injection injected [PAD] operating
# no or without wall bleeding infectiontor cancer and was wereicia bladder

# %% [markdown]
# Metrics

# %%
###define semantic similarity
module_url = "https://tfhub.dev/google/universal-sentence-encoder-large/4"
embed = hub.load(module_url)
def semantic_sim(messages):
        #messages = ["That band rocks!", "That song is really cool."]
        scores = []
        for m in messages:
            message_embeddings = embed(m)["outputs"]
            a, b = message_embeddings[0].numpy(), message_embeddings[1].numpy()
            scores.append(np.inner(a,b))
        return np.mean(scores)

###define Bleu score
def bleu(candidates, references):

    return bleu_score(candidates, references, max_n=2, weights=[0.5, 0.5])

###define sentiment similarity

def sentiment_sim(messages):
    Scores = []
    for message in messages:
        score1 = sia.polarity_scores(message[0])
        score2 = sia.polarity_scores(message[1])
        a = np.array([score1["neg"], score1["neu"], score1["pos"]])
        b = np.array([score2["neg"], score2["neu"], score2["pos"]])
        Scores.append(np.inner(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))
    return np.mean(Scores)

###top_k prediction
from collections import Counter
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))
def top_k(prediction):
    percentiles = [5, 10, 20, 50]
    top_words = defaultdict(list)
    prediction = " ".join(prediction)

    tempt = []
    for x in prediction.split(): tempt += x.split()
    c = Counter(tempt)

    words = [k for k, v in sorted(c.items(), key=lambda item: item[1], reverse=True) if k not in stops]
    for p in percentiles:
        top_words[p].extend(words[:int(p*len(words)/100)+1])

    return top_words

###top-k accuracy
def top_k_accuracy(top, multi):
    acc = {}
    for k in top.keys():
        res = []
        for t,m in zip(top[k], multi):
            ans = False
            for c in set(m.split()):
                if c in t: ans = True
            res.append(ans)
        acc[k] = sum(res)/len(res)
    return acc

from geopy.geocoders import Nominatim
from functools import partial
geolocator = Nominatim(user_agent = "geoapiExercises")
geocode = partial(geolocator.geocode, language="en")
#location = geocode("london")
#print("Country Name: ", location)

def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

def expand_keyword(label):
    res = []
    location = geocode(label)
    res.extend(location.raw["display_name"].split(", "))
    res = [x for x in res if not has_numbers(x)]
    return res
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Now let's count keywords that we just generated
count = 0
for i in range(100):
    res = top_k(Prediction[i])

    if isinstance(label.iloc[i], float):
        continue
    for keyword in label.iloc[i].split():
        if keyword in res[50]:
            count += 1
print(count)
# Out:
# 33

# %% [markdown]
# Refer to the paper for the tips to improve reconstruction
